# %%
from __future__ import unicode_literals, print_function, division
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

import numpy as np
import pandas as pd

import os
import re
import random

# %%
def normalize_sentence(df, part):
    sentence = df[part].str
    sentence = sentence.encode('utf-8', errors='ignore').str.decode('utf-8')
    return sentence

def read_sentence(df, first, second):
    sentence1 = normalize_sentence(df, first)
    sentence2 = normalize_sentence(df, second)
    return sentence1, sentence2

def read_file(file, first, second):
    df = pd.read_csv(file, delimiter=' , ', header=None, names=[first, second])
    return df

def process_data(first, second, MAX_LENGTH = 15):
    df = read_file('/content/ferdosi.txt', first, second)
    print("Read %s sentence pairs" % len(df))
    
    sentence1, sentence2 = read_sentence(df, first, second)

    source = Language()
    target = Language()
    pairs = []

    for i in range(len(df)):
        if len(sentence1[i].split(' ')) < MAX_LENGTH and len(sentence2[i].split(' ')) < MAX_LENGTH :
            full = [sentence1[i], sentence2[i]]
            source.add_sentence(sentence1[i])
            target.add_sentence(sentence2[i])
            pairs.append(full)
    
    return source, target, pairs

# %%
SOS_token = 0
EOS_token = 1
MAX_LENGTH = 15

class Language:
    def __init__(self):
        self.word2index = {}
        self.word2count = {}
        self.index2word = {0: "SOS", 1: "EOS"}
        self.n_words = 2

    def add_sentence(self, sentence):
        for word in sentence.split(' '):
            self.add_word(word)
    
    def add_word(self, word):
        if word not in self.word2index:
            self.word2index[word] = self.n_words
            self.word2count[word] = 1
            self.index2word[self.n_words] = word
            self.n_words += 1
        else:
            self.word2count[word] += 1

# %%
MAX_LENGTH = 15

def indexes_from_sentence(language, sentence):
    words =  [language.word2index[word] for word in sentence.split(' ')]
    return [SOS_token] + words + [EOS_token] * (MAX_LENGTH - len(words) - 1)

def tensor_from_sentence(language, sentence):
    indexes = indexes_from_sentence(language, sentence)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype= torch.long, device = device).view(-1, 1)

def tensors_from_pair(source, target, pair):
    input_tensor = tensor_from_sentence(source, pair[0])
    target_tensor = tensor_from_sentence(target, pair[1])
    return (input_tensor, target_tensor)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
class Encoder(nn.Module):
    def __init__(self, input_dim, hidden_dim, embed_dim, decoder_hidden_dim = 512, num_layers=1):
        super(Encoder, self).__init__()

        self.input_dim = input_dim
        self.hidden_dim = hidden_dim
        self.embed_dim = embed_dim
        self.num_layers = num_layers

        self.embedding = nn.Embedding(self.input_dim, self.embed_dim)
        self.hidden_fc = torch.nn.Sequential(
            torch.nn.Linear(hidden_dim, decoder_hidden_dim),
            torch.nn.ReLU(inplace=True)
        )
        self.lstm = nn.LSTM(self.embed_dim, self.hidden_dim, num_layers = self.num_layers)

    def forward(self, source):
        # (1,1,-1)
        embedded = self.embedding(source)
        outputs, (hidden, cell) = self.lstm(embedded)
        return outputs, hidden, cell

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, hidden_dim, embed_dim, num_layers):
        super(Decoder, self).__init__()

        self.output_dim = output_dim
        self.hidden_dim = hidden_dim
        self.embed_dim = embed_dim
        self.num_layers = num_layers
        self.dropout = nn.Dropout(0.1)


        self.embedding = nn.Embedding(output_dim, self.embed_dim)
        self.lstm = nn.LSTM(self.embed_dim, self.hidden_dim, num_layers = self.num_layers)
        self.out = nn.Linear(self.hidden_dim, self.output_dim)
        self.softmax = nn.LogSoftmax(dim = -1)

    def forward(self, input, hidden, cell):
        input = input.view(1, -1)
        embedded = self.embedding(input)
        embedded = self.dropout(embedded)
        output, (hidden, cell) = self.lstm(embedded, (hidden, cell))       
        prediction = self.softmax(self.out(output[0]))

        return prediction, hidden, cell

# %%
class Seq2seq(nn.Module):
    def __init__(self, encoder, decoder, device, MAX_LENGTH=MAX_LENGTH):
        super().__init__()

        
        self.encoder = encoder
        self.decoder = decoder
        self.device = device
    
    def forward(self, source, target, teacher_forcing_ratio = 0.5):
        source_length = source.shape[0]
        target_length = target.shape[0]
        batch_size = target.shape[1]
        vocab_size = self.decoder.output_dim

        outputs = torch.zeros(target_length,  batch_size, vocab_size).to(self.device)
        encoder_output, encoder_hidden, cell = self.encoder(source)
        decoder_hidden = encoder_hidden.to(self.device)

        decoder_input = torch.tensor([SOS_token], device = self.device)

        for i in range(target_length):
            decoder_output, decoder_hidden, cell = self.decoder(decoder_input, decoder_hidden, cell)
            outputs[i] = decoder_output
            teacher_force = random.random() < teacher_forcing_ratio
            top_prob, top_ind = decoder_output.topk(1)
            input = target[i] if teacher_force else top_ind
            if teacher_force == False and input.item() == EOS_token:
                break
            
        return outputs

# %%
def get_batches(source, target, axis, batch_size):
    num_batches = int(np.ceil(source.shape[axis] * 1.0 / batch_size))

    for batch in range(num_batches):
        yield batch, source[:, batch * batch_size: min((batch + 1) * batch_size, source.shape[axis])], target[:, batch * batch_size: min((batch + 1) * batch_size, source.shape[axis])]

# %%
teacher_forcing_ratio = 0.5

def clacModel(model, input_tensor, target_tensor, model_optimizer, criterion):
    
    model_optimizer.zero_grad()

    input_length = input_tensor.size(0)
    loss = 0
    epoch_loss = 0
    output = model(input_tensor, target_tensor)

    num_iter = output.size(0)

    #calculate the loss from a predicted sentence with the expected result
    for ot in range(num_iter):
        loss += criterion(output[ot], target_tensor[ot])

    loss.backward()
    model_optimizer.step()
    epoch_loss = loss.item() / num_iter

    return epoch_loss

# %%
def train(model, source, target, pairs, optimizer, batch_size = 128):
    model.train()

    criterion = nn.NLLLoss()
    total_loss_iterations = 0
    loss = 0
    training_pairs = [tensors_from_pair(source, target, random.choice(pairs)) for i in range(num_iteration)]
    
    print("num of iterations is", batch_size)
    for iter in range(1, batch_size + 1):
        training_pair = training_pairs[iter - 1]
        input_tensor = training_pair[0]
        target_tensor = training_pair[1]

        total_loss_iterations += clacModel(model, input_tensor, target_tensor, optimizer, criterion)
        loss += total_loss_iterations
        
        if iter % 100 == 0:
            avarage_loss = total_loss_iterations / 50
            total_loss_iterations = 0
            print('%d %.4f' % (iter, avarage_loss))        
            
    torch.save(model.state_dict(), 'mytraining.pt')
    return model , (loss / iter)

# %%
def evaluate(model, input_lang, output_lang, sentences, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensor_from_sentence(input_lang, sentences[0])
        output_tensor = tensor_from_sentence(output_lang, sentences[1])
    
        decoded_words = []
    
        output = model(input_tensor, output_tensor)
    
        for ot in range(output.size(0)):
            topv, topi = output[ot].topk(1)

            if topi[0].item() == EOS_token:
                decoded_words.append('<EOS>')
                break
            else:
                decoded_words.append(output_lang.index2word[topi[0].item()])
    
    return decoded_words

def evaluateRandomly(model, source, target, pairs, n=5):
    for i in range(n):
        pair = random.choice(pairs)
        print("source {}".format(pair[0]))        
        output_words = evaluate(model, source, target, pair)
        output_sentence = ' '.join(output_words)
        print("target {}".format(pair[1]))
        print("predicted {}".format(output_sentence))

# %%
source, target, pairs = process_data('first', 'second')

randomize = random.choice(pairs)
print('random sentence {}'.format(randomize))

#print number of words
input_size = source.n_words
output_size = target.n_words
print('Input : {} Output : {}'.format(input_size, output_size))

embed_size = 256
hidden_size = 512
num_layers = 1
num_iteration = 1000

#create encoder-decoder model
DEC_HID_DIM = 512
encoder = Encoder(input_size, hidden_size, embed_size,DEC_HID_DIM, num_layers)
decoder = Decoder(output_size, hidden_size, embed_size, num_layers)

model = Seq2seq(encoder, decoder, device).to(device)

#print model 
print(encoder)
print(decoder)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   if sys.path[0] == '':
# Read 49609 sentence pairs
# random sentence ['بدو گفت زینسان که گفتی بساز', 'مرا کردی از خون او بی نیاز']
# Input : 12458 Output : 13071
# Encoder(
#   (embedding): Embedding(12458, 256)
#   (hidden_fc): Sequential(
#     (0): Linear(in_features=512, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#   )
#   (lstm): LSTM(256, 512)
# )
# Decoder(
#   (dropout): Dropout(p=0.1, inplace=False)
#   (embedding): Embedding(13071, 256)
#   (lstm): LSTM(256, 512)
#   (out): Linear(in_features=512, out_features=13071, bias=True)
#   (softmax): LogSoftmax(dim=-1)
# )

# %%
from time import time

epochs = 300
optimizer = optim.Adam(model.parameters(), lr=0.001)

for i in range(epochs):

    start_time = time()
    
    model, train_loss = train(model, source, target, pairs, optimizer, 128)
    evaluateRandomly(model, source, target, pairs)

    print(f'\tTrain Loss: {train_loss:.3e} | Train PPL: {np.exp(train_loss):.3e}')

    end_time = time()

    print("ended in: ", end_time - start_time, "sec")
# Out:
# num of iterations is 128
# 100 4.7280
# source بپرهیز و پیچان شو از خشم اوی
# target ندیدی که خشم اورد چشم اوی
# predicted SOS که و و و <EOS>
# source سه پور جوان را سپهدار گفت
# target پراگنده باشید با گنج جفت
# predicted SOS که و و و <EOS>
# source سواریش دیدم چو سرو سهی
# target خردمند و با زیب و با فرهی
# predicted SOS که و و و <EOS>
# source بپیچید زان پس سوی دست راست
# target بدانست کان روز روز بلاست
# predicted SOS که و و و <EOS>
# source همه سخته باید که راند سخن
# target که گفتار نیکو نگردد کهن
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.009e+02 | Train PPL: 6.388e+43
# ended in:  62.04293370246887 sec
# num of iterations is 128
# 100 4.8008
# source جهان دیده باید عنان دار کس
# target سنان و سپر بایدش یار بس
# predicted SOS که و و و <EOS>
# source ز شه خواستند ان زمان زینهار
# target فروریختند الت کارزار
# predicted SOS که از و و <EOS>
# source همان بیژن گیو برجست زود
# target کجا بود در جنگ برسان دود
# predicted SOS که و و و <EOS>
# source سه دیگر که نزدیک موبد برند
# target گزیت و سر باژها بشمرند
# predicted SOS که از و و <EOS>
# source همه چین و توران سراسر مراست
# target به هیتال بر نیز فرمان رواست
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.030e+02 | Train PPL: 5.180e+44
# ended in:  64.64373683929443 sec
# num of iterations is 128
# 100 4.7747
# source به بیژن چنین گفت گیو دلیر
# target که مشتاب در چنگ این نره شیر
# predicted SOS که و و و <EOS>
# source چو فرمان دهد خسرو زود یاب
# target نگیرم برین کار کردن شتاب
# predicted SOS که و و و <EOS>
# source ببردند هر دو به گوهر فروش
# target که این را بها کن بدانش بکوش
# predicted SOS که و و و <EOS>
# source سپیده چو برزد سر از کوه بر
# target پدید امد ان زرد رخشان سپر
# predicted SOS که و و و <EOS>
# source چه بندی دل اندر سرای سپنج
# target که دانا نداند یکی را ز پنج
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.026e+02 | Train PPL: 3.629e+44
# ended in:  64.14504981040955 sec
# num of iterations is 128
# 100 4.7635
# source براشفت خسرو به اسفندیار
# target به زندان و بندش فرستاد خوار
# predicted SOS که و و و <EOS>
# source زن و کودکانشان بیارم ز پیش
# target کنمشان همه بنده شهر خویش
# predicted SOS که و و و <EOS>
# source بیامد رسن بستد از پیشکار
# target شد ان کار دشوار بر شاه خوار
# predicted SOS که و و و <EOS>
# source کنون ما نداریم پایاب اوی
# target نه پیچیم با بخت شاداب اوی
# predicted SOS که از و و <EOS>
# source خداوند گردنده خورشید و ماه
# target کزویست پیروزی و دستگاه
# predicted SOS که از و و <EOS>
# 	Train Loss: 1.008e+02 | Train PPL: 6.097e+43
# ended in:  62.947596073150635 sec
# num of iterations is 128
# 100 4.7451
# source سپاهی فراوان بر پیلتن
# target ز کشمیر و کابل شدند انجمن
# predicted SOS که و و و <EOS>
# source چو رستم بیاید بدین رزمگاه
# target بدیها سراید همه بر سپاه
# predicted SOS که و و و <EOS>
# source نباشد و گرچه بود درنهان
# target که بدخواه تو دور بادازجهان
# predicted SOS که و و و <EOS>
# source خنک انک چون تو پسر زاید او
# target همی فر گیتی بیفزاید او
# predicted SOS که و و و <EOS>
# source که من در نبشته چنین یافتم
# target بدان ارزو تیز بشتافتم
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.014e+02 | Train PPL: 1.096e+44
# ended in:  61.81389904022217 sec
# num of iterations is 128
# 100 4.6136
# source گر از امدن دم زنی یک زمان
# target براید همی کامه بدگمان
# predicted SOS به و و و <EOS>
# source بدل مهربان و بتن چاره جوی
# target اگر تو خداوند رخشی بگوی
# predicted SOS به و و و <EOS>
# source ببردند نامه بر کیقباد
# target سخن نیز ازین گونه کردند یاد
# predicted SOS به و و و <EOS>
# source بهایست خرم در اردیبهشت
# target همه خاک عنبر همه زر خشت
# predicted SOS به و و و <EOS>
# source دل ما مکن شهریارا نژند
# target میاور به جان خود و من گزند
# predicted SOS به و و و <EOS>
# 	Train Loss: 9.783e+01 | Train PPL: 3.058e+42
# ended in:  59.619943380355835 sec
# num of iterations is 128
# 100 4.5119
# source کنون نیست امروز روز درنگ
# target جهان گشت بر مرد بیدار تنگ
# predicted SOS به و و و <EOS>
# source براورد رازی که بود از نهفت
# target بدان نامداران ایران بگفت
# predicted SOS به و و و <EOS>
# source سپاهی بد از جاثلقیان روم
# target که پیدا نبد از پی نعل بوم
# predicted SOS به و و و <EOS>
# source بدانید کامد به سر کار کرم
# target گذشت اختر و روز بازار کرم
# predicted SOS به و و و <EOS>
# source به نزدیک خاقان فرستاد شاه
# target دومنزل همی رفت با او به راه
# predicted SOS به و و و <EOS>
# 	Train Loss: 9.806e+01 | Train PPL: 3.855e+42
# ended in:  61.293400287628174 sec
# num of iterations is 128
# 100 4.6053
# source بدو گفت نستاو زین در بگرد
# target تو ایدر غریبی وبی پای مرد
# predicted SOS که و و و <EOS>
# source غو دیده باید که از دیدگاه
# target کانوشه سر و تاج گشتاسپ شاه
# predicted SOS که و و و <EOS>
# source کزو بودمان زور و فر و هنر
# target ازو دردمندی و هم زو گهر
# predicted SOS که و و و <EOS>
# source سه خانه برفتی سرافراز پیل
# target بدیدی همه رزم گه از دو میل
# predicted SOS که و و و <EOS>
# source سیاوش بدو گفت هرگز مباد
# target که از بهر دل سر دهم من به باد
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.700e+01 | Train PPL: 1.345e+42
# ended in:  60.79542636871338 sec
# num of iterations is 128
# 100 4.7100
# source غلامی بیاراست از خویشتن
# target سخن گوی و شایسته انجمن
# predicted SOS به و و و <EOS>
# source زبر چون بهشتست و دوزخ به زیر
# target بد ان را که باشد به یزدان دلیر
# predicted SOS به و و و <EOS>
# source نشانهای بند تو دارد تنم
# target به زیر کمند تو بد گردنم
# predicted SOS به و و و <EOS>
# source ز هر سو سپه بیکران کشته شد
# target زمانه همی بر بدی گشته شد
# predicted SOS به و و و <EOS>
# source بمانم پر از حسرت و درد و خشم
# target پر از ارزو دل پر از اب چشم
# predicted SOS به و و و <EOS>
# 	Train Loss: 1.004e+02 | Train PPL: 4.020e+43
# ended in:  60.73224759101868 sec
# num of iterations is 128
# 100 4.7080
# source سپهر اندر ان جنگ نظاره بود
# target ستاره شمر سخت بیچاره بود
# predicted SOS به از و و <EOS>
# source ز پوشیدنی هم ز گستردنی
# target ز هر سو بیورد اوردنی
# predicted SOS به از و و <EOS>
# source تومهمان ما بود باید نخست
# target پس این پاسخ نامه بایدت جست
# predicted SOS به از و و <EOS>
# source که شاه جهان جاودان زنده باد
# target بزرگان گیتی ورا بنده باد
# predicted SOS به از و و <EOS>
# source چنین گفت زان پیل بر پهلوی
# target که ای گنج اگر دشمن خسروی
# predicted SOS به از و و <EOS>
# 	Train Loss: 9.813e+01 | Train PPL: 4.160e+42
# ended in:  58.99683356285095 sec
# num of iterations is 128
# 100 4.7126
# source به بد مهری من روانم مسوز
# target به من باز بخش و دلم برفروز
# predicted SOS به و و و <EOS>
# source بزد نای رویین و رویینه خم
# target برامد ز در ناله گاودم
# predicted SOS به از و و <EOS>
# source بنه بر نهاد و سپه بر نشاند
# target دمان از پس شاه ترکان براند
# predicted SOS به و و و <EOS>
# source ازو شاه ایران شود دردمند
# target بترسد ز پیروز بخت بلند
# predicted SOS به و و و <EOS>
# source چو پیدا شود کژی و کاستی
# target درفشان شود پیش تو راستی
# predicted SOS به از و و <EOS>
# 	Train Loss: 1.012e+02 | Train PPL: 9.063e+43
# ended in:  61.807135820388794 sec
# num of iterations is 128
# 100 4.6114
# source از ایشان صد اسپ افگن از ما یکی
# target همان صد به پیش یکی اندکی
# predicted SOS که و و و <EOS>
# source بداند شمار سپهر بلند
# target در پادشاهی و راه گزند
# predicted SOS که و و و <EOS>
# source نگه کرد خسرو پس پشت خویش
# target ازان چار بهرام را دید پیش
# predicted SOS که و و و <EOS>
# source هنرهای شاهانش اموختم
# target از اندرز فام خرد توختم
# predicted SOS که و و و <EOS>
# source به خوبی ز ره بازگردانمش
# target سخن با هزینه برافشانمش
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.796e+01 | Train PPL: 3.506e+42
# ended in:  63.652204751968384 sec
# num of iterations is 128
# 100 4.7066
# source چو بشنید بهرام و اندیشه کرد
# target ز دانش غم نارسیده نخورد
# predicted SOS که و و و <EOS>
# source ز گاه منوچهر تا کیقباد
# target ازان نامداران که داریم یاد
# predicted SOS که و و و <EOS>
# source یکی گفت کین شاه دیوانه شد
# target خرد با دلش سخت بیگانه شد
# predicted SOS که و و و <EOS>
# source کزین بگذری بینی اباد شهر
# target کزان شهرها بر توان داشت بهر
# predicted SOS که و و و <EOS>
# source به سو طلایه پدیدار کرد
# target سر خفته از خواب بیدار کرد
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.994e+01 | Train PPL: 2.526e+43
# ended in:  62.927565574645996 sec
# num of iterations is 128
# 100 4.6199
# source زمانه شد از درد او با خروش
# target تو گفتی که هامون برامد به جوش
# predicted SOS که و و و <EOS>
# source کشانی وسغدی شدند انجمن
# target پر از اب رو کودک و مرد وزن
# predicted SOS که و و و <EOS>
# source همی بود ازین گونه تا ماه نو
# target برامد نشست از برگاه نو
# predicted SOS که و و و <EOS>
# source که ان جفت من مرغ با دستگاه
# target به دستان و شمشیر کردش تباه
# predicted SOS که و و و <EOS>
# source جهاندار فرزند هرمزد شاه
# target که زیبای تاج است و زیبای گاه
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.886e+01 | Train PPL: 8.564e+42
# ended in:  60.9799599647522 sec
# num of iterations is 128
# 100 4.6266
# source ز تخم کیان کس جز از تو نماند
# target که با تاج بر تخت شاید نشاند
# predicted SOS که از و و <EOS>
# source بگیتی هرانکس که او چون تو بود
# target سرش پر ز گرد ودلش پر ز دود
# predicted SOS که و و و <EOS>
# source براشفت با طوس و شد چون پلنگ
# target که این جای خوابست گر دشت جنگ
# predicted SOS که و و و <EOS>
# source خرامان شدم پیش ان ارجمند
# target یکی تخت پیروزه دیدم بلند
# predicted SOS که و و و <EOS>
# source بترسید ازو یار هومان چو دید
# target که بر مهتر او چنان بد رسید
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.749e+01 | Train PPL: 2.189e+42
# ended in:  64.30193734169006 sec
# num of iterations is 128
# 100 4.6335
# source بفرمود تا گرد کردند شاه
# target ببخشید زان پس همه بر سپاه
# predicted SOS که از و و <EOS>
# source بیارم نشانم بر تخت ناز
# target ازان پس گشایم در گنج باز
# predicted SOS که از و و <EOS>
# source تو ای بافرین شاه فرزند من
# target نگر تا نیوشی یکی پند من
# predicted SOS که از و و <EOS>
# source وزان روی بهرام شد پر ز درد
# target پشیمان شده زان همه کارکرد
# predicted SOS که از و و <EOS>
# source چو بهرام با دخت شنگل بساخت
# target زن او همی شاه گیتی شناخت
# predicted SOS که از و و <EOS>
# 	Train Loss: 9.927e+01 | Train PPL: 1.291e+43
# ended in:  65.42187833786011 sec
# num of iterations is 128
# 100 4.7896
# source بیاویخت از نیزه ران بره
# target ببست اندر اندیشه دل یکسره
# predicted SOS ز و و و <EOS>
# source چو کیخسرو امد بکین خواستن
# target جهان ساز نو خواست اراستن
# predicted SOS ز و و و <EOS>
# source سپهدار ایران ز پشت سپاه
# target بشد دور با کهتری نیک خواه
# predicted SOS ز و و و <EOS>
# source به نیزه ز اسپت نهم بر زمین
# target ازان پس نه پرخاش جویی نه کین
# predicted SOS ز و و و <EOS>
# source ز فرش جهان شد چو باغ بهار
# target هوا پر ز ابر و زمین پرنگار
# predicted SOS ز و و و <EOS>
# 	Train Loss: 1.028e+02 | Train PPL: 4.584e+44
# ended in:  65.44258546829224 sec
# num of iterations is 128
# 100 4.6552
# source که با لشکر امد همی پیش تو
# target نبد اگه از رای کم بیش تو
# predicted SOS ز از و و <EOS>
# source کنون اندرین هم به کار اوریم
# target بدو در فراوان نگار اوریم
# predicted SOS ز و و و <EOS>
# source همه رزمگه شد چو دریای خون
# target درفش سپهدار ایران نگون
# predicted SOS ز از و و <EOS>
# source برین همنشان تا ز خم سپهر
# target پدید امد ان زیور تاج مهر
# predicted SOS ز و و و <EOS>
# source چو برگشته بخت او شد نگون
# target بریدش سر از تن بسان هیون
# predicted SOS ز از و و <EOS>
# 	Train Loss: 1.017e+02 | Train PPL: 1.514e+44
# ended in:  64.55713844299316 sec
# num of iterations is 128
# 100 4.7041
# source یکی مرد بود اندر ان روزگار
# target ز دشت سواران نیزه گذار
# predicted SOS که و و و <EOS>
# source همی گفت و می بود جوشان بسی
# target از ایران ندادند پاسخ کسی
# predicted SOS که و و و <EOS>
# source تو بر خویشتن گر کنی صدگزند
# target چه اسانی اید بدان ارجمند
# predicted SOS که و و و <EOS>
# source کنون از تو اندازه گیریم راست
# target نباید برین بر فزون و نه کاست
# predicted SOS که و و و <EOS>
# source یکی باد برخاست و گردی سیاه
# target بشد روشنایی ز خورشید و ماه
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.012e+02 | Train PPL: 9.262e+43
# ended in:  64.62032389640808 sec
# num of iterations is 128
# 100 4.7585
# source چو بیدار گشتند زیشان سران
# target کشیدیم شمشیر و گرز گران
# predicted SOS که و و و <EOS>
# source مگر ناگهان بر سر ان گروه
# target فرود ارم این گشن لشکر چو کوه
# predicted SOS که و و و <EOS>
# source بر و بوم و گنج و سپاهت مراست
# target همان تخت و زرین کلاهت مراست
# predicted SOS که و و و <EOS>
# source نژند ان زمان شد که بیداد شد
# target به بیدادگر بندگان شاد شد
# predicted SOS که و و و <EOS>
# source گر ایدونک اید زمانم فراز
# target به لشکر ندارد جهاندار باز
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.012e+02 | Train PPL: 8.768e+43
# ended in:  64.21727180480957 sec
# num of iterations is 128
# 100 4.5071
# source برفتند باز ان دو بیداد شوم
# target یکی سوی ترک و یکی سوی روم
# predicted SOS که و و و <EOS>
# source چو لشکر شد از خواسته بی نیاز
# target برو ناگذشته زمانی دراز
# predicted SOS که و و و <EOS>
# source سبک خنجر اندر دهانش نهاد
# target ز دادار نیکی دهش کرد یاد
# predicted SOS که و و و <EOS>
# source که اویست جاوید فریادرس
# target بسختی نگیرد جز او دست کس
# predicted SOS که و و و <EOS>
# source که بالاش با چرخ همبر بود
# target تنش خون خورد بار او سر بود
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.638e+01 | Train PPL: 7.189e+41
# ended in:  63.600499391555786 sec
# num of iterations is 128
# 100 4.6565
# source جفا پیشگان ترا هم کنون
# target بیاویزم از دارشان سرنگون
# predicted SOS که و و و <EOS>
# source ز گفتارشان شاد شد شهریار
# target ببخشیدشان گوهر شاهوار
# predicted SOS که و و و <EOS>
# source چو خورشید روشن بیاراست گاه
# target طلایه بیامد ز نزدیک شاه
# predicted SOS که و و و <EOS>
# source ز نوشین روان شاه فرخ نژاد
# target جهانگیر وزنده کن کیقباد
# predicted SOS که و و و <EOS>
# source کسی کو بپیمود روی زمین
# target جهان دید و ارام و پرخاش و کین
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.980e+01 | Train PPL: 2.201e+43
# ended in:  64.21316695213318 sec
# num of iterations is 128
# 100 4.7417
# source گر ایدونک پشت من ارد به خم
# target شما دیر مانید خوار و دژم
# predicted SOS که و و و <EOS>
# source خداوند نام و خداوند گنج
# target خداوند شمشیر و خفتان و رنج
# predicted SOS که و و و <EOS>
# source به دارو چو یک هفته بستی پزشک
# target دگر هفته خون امدی چون سرشک
# predicted SOS که و و و <EOS>
# source چوبشنید داننده گفتار زن
# target بخندید بر باره گامزن
# predicted SOS که و و و <EOS>
# source ازین دودمان شاه جمهور بود
# target که رایش ز کردار بد دور بود
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.001e+02 | Train PPL: 3.099e+43
# ended in:  64.90494155883789 sec
# num of iterations is 128
# 100 4.6522
# source به خواری تنش را برارم بدار
# target ز دهقان و تازی و رومی شمار
# predicted SOS که و و و <EOS>
# source نبودی ازین پیش تو بدکنش
# target ز نفرین بترسیدی و سرزنش
# predicted SOS که و و و <EOS>
# source بیاراست لشکر سپهدار طوس
# target بپیلان جنگی و مردان و کوس
# predicted SOS که و و و <EOS>
# source سرافراز گودرز ازان انجمن
# target بهر کار باشد ترا رای زن
# predicted SOS که و و و <EOS>
# source به یک هفته زان گونه بودند شاد
# target به هشتم در گنجها برگشاد
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.943e+01 | Train PPL: 1.520e+43
# ended in:  64.4288215637207 sec
# num of iterations is 128
# 100 4.6919
# source چو پیمان همه کرده باشیم راست
# target ز من خواسته هرچ خسرو بخواست
# predicted SOS که و و و <EOS>
# source همه مرز توران شکسته دلند
# target ز تیمار دل را همی بگسلند
# predicted SOS که و و و <EOS>
# source چنین داد پاسخ که ناتندرست
# target که دل را جز از شادمانی نجست
# predicted SOS که و و و <EOS>
# source ز شاهان ز ضحاک بتر کسی
# target نیامد پدیدار بجویی بسی
# predicted SOS که و و و <EOS>
# source رسیدم ز هر سو به گرد جهان
# target خبر یافتم ز اشکار و نهان
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.007e+02 | Train PPL: 5.218e+43
# ended in:  66.45979809761047 sec
# num of iterations is 128
# 100 4.5942
# source هیونی ز نزدیک افراسیاب
# target چو اتش بیامد به هنگام خواب
# predicted SOS که از و و <EOS>
# source کنون تا کرا بد دهد کردگار
# target که پیروز گردد ازین کارزار
# predicted SOS که از و و <EOS>
# source چنین داد پاسخ که شب تیره شد
# target مرا سر ز گفتار تو خیره شد
# predicted SOS که از و و <EOS>
# source چو نزدیکی خان دهقان رسید
# target بسی مردم از خانه بیرون دوید
# predicted SOS که از و و <EOS>
# source چنین داد پاسخ که امد نشان
# target ز گفتار ان مهتر سرکشان
# predicted SOS که از و و <EOS>
# 	Train Loss: 9.730e+01 | Train PPL: 1.804e+42
# ended in:  64.50061821937561 sec
# num of iterations is 128
# 100 4.8211
# source نه ما زو به مام و پدر کمتریم
# target نه بر تخت شاهی نه اندر خوریم
# predicted SOS که و و و <EOS>
# source درختان همه خشک و ویران سرای
# target همه مرز بی مردم و چارپای
# predicted SOS که و و و <EOS>
# source چنان بود یک چند و اکنون چنین
# target چه نفرین شنیدی و چه افرین
# predicted SOS که و و و <EOS>
# source تو دانی که از هندوان صدهزار
# target بود پیش من کمتر از یک سوار
# predicted SOS که و و و <EOS>
# source چنان ساخت جای خرام و خورش
# target که تن یابد از خوردنی پرورش
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.038e+02 | Train PPL: 1.242e+45
# ended in:  67.38909959793091 sec
# num of iterations is 128
# 100 4.6574
# source پزشک خردمند را داد و گفت
# target که با پاک رایت خرد باد جفت
# predicted SOS ز و و و <EOS>
# source بدین داستان زد یکی مهرنوش
# target پرستار با هوش و پشمینه پوش
# predicted SOS ز و و و <EOS>
# source برین باره گامزن برنشین
# target که زیر تو اندر نوردد زمین
# predicted SOS ز و و و <EOS>
# source چهارم چنین گفت کان مرغزار
# target که بینی پر از سبزه و جویبار
# predicted SOS ز و و و <EOS>
# source یکی را برهنه سر و پای و سفت
# target نه ارام و خورد و نه جای نهفت
# predicted SOS ز و و و <EOS>
# 	Train Loss: 9.902e+01 | Train PPL: 1.009e+43
# ended in:  67.4023015499115 sec
# num of iterations is 128
# 100 4.5875
# source برافرازم اندر جهان داد را
# target کنم تازه ایین میلاد را
# predicted SOS به و و و <EOS>
# source چه جویی از این تیره خاک نژند
# target که هم بازگرداندت مستمند
# predicted SOS به و و و <EOS>
# source بپیچید و بر زد یکی سرد باد
# target به زاری بران جامه بر جان بداد
# predicted SOS به و و و <EOS>
# source بدو کفشگر گفت کای خوب چهر
# target به رنج ی بگویی به بوزرجمهر
# predicted SOS به و و و <EOS>
# source وزان پس نیاسایم از پاسخت
# target ز فرمان و رای و دل فرخت
# predicted SOS به و و و <EOS>
# 	Train Loss: 9.821e+01 | Train PPL: 4.478e+42
# ended in:  68.56669354438782 sec
# num of iterations is 128
# 100 4.6221
# source نوندی به هر سو برافگند گیو
# target یکی نامه از شاه وز گیو نیو
# predicted SOS به و و و <EOS>
# source چو خورشید تیغ از میان برکشید
# target سپاه شب تیره شد ناپدید
# predicted SOS به و و و <EOS>
# source چنین گفت با مادر اسفندیار
# target که با من همی بد کند شهریار
# predicted SOS به و و و <EOS>
# source بفرمود تا کوس بیرون برند
# target سرافراز پیلان به هامون برند
# predicted SOS به و و و <EOS>
# source مگر نیز فرزند بینم یکی
# target که ارام دل باشدم اندکی
# predicted SOS به و و و <EOS>
# 	Train Loss: 9.835e+01 | Train PPL: 5.187e+42
# ended in:  69.00143027305603 sec
# num of iterations is 128
# 100 4.7086
# source بیابان و یک ساله دریا و کوه
# target برفتیم با داغ دل یک گروه
# predicted SOS که و و و <EOS>
# source چرا تاختی پیش فرزند اوی
# target پرستنده ای تو نه پیوند اوی
# predicted SOS که و و و <EOS>
# source ز شاهان نجوید کسی جای اوی
# target مگر تیره باشد دل و رای اوی
# predicted SOS که و و و <EOS>
# source روانم روان ترا بنده باد
# target دل هرک زین شاد شد کنده باد
# predicted SOS که و و و <EOS>
# source منش را دگر کرد و پاسخ دگر
# target توگفتی بپروین براورد سر
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.001e+02 | Train PPL: 3.040e+43
# ended in:  72.48362517356873 sec
# num of iterations is 128
# 100 4.7620
# source همی خواهم از دادگر یک خدای
# target که چندان بمانم به گیتی به جای
# predicted SOS که و و و <EOS>
# source ز گفتار و کردار ان شوخ مرد
# target نشد هیچ مهبود را روی زرد
# predicted SOS که و و و <EOS>
# source به بزم و به رزم و به روز شکار
# target جهان بین ندیدست چون او سوار
# predicted SOS که و و و <EOS>
# source همه سربسر مر ترا بنده ایم
# target بفرمان و رایت سرافگنده ایم
# predicted SOS که از و و <EOS>
# source دگر باره گردی زبان اوری
# target فریبنده مردی ز دشت هری
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.024e+02 | Train PPL: 3.050e+44
# ended in:  68.69532561302185 sec
# num of iterations is 128
# 100 4.8103
# source چو بودم جوان در برم داشتی
# target به پیری چرا خوار بگذاشتی
# predicted SOS ز و و و <EOS>
# source شگفتی بگیتی ز رستم بس است
# target کزو داستان بر دل هرکس است
# predicted SOS ز و و و <EOS>
# source همان نیز گودرز کشوادگان
# target سرنامداران ازادگان
# predicted SOS ز و و و <EOS>
# source بترسید و پرسید زان ترجمان
# target که ای مرد بیدار نیکی گمان
# predicted SOS ز و و و <EOS>
# source پی کین تو افگندی اندر جهان
# target ز بهر سیاوش میان مهان
# predicted SOS ز و و و <EOS>
# 	Train Loss: 1.023e+02 | Train PPL: 2.587e+44
# ended in:  68.21338486671448 sec
# num of iterations is 128
# 100 4.7545
# source سپیده دمان مرد با مهر شاه
# target بر موبد موبد امد پگاه
# predicted SOS که و و و <EOS>
# source همی تاخت یکسان چو روز شکار
# target ببازی همی امدش کارزار
# predicted SOS که و و و <EOS>
# source ز تیر خدنگ اسپ هومان بخست
# target تن بارگی گشت با خاک پست
# predicted SOS که و و و <EOS>
# source همه لشکر از بهر ان ارجمند
# target زبان برگشادند یکسر ز بند
# predicted SOS که و و و <EOS>
# source ستودش فراوان و کرد افرین
# target چنین گفت کای شهریار زمین
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.012e+02 | Train PPL: 8.719e+43
# ended in:  67.39866423606873 sec
# num of iterations is 128
# 100 4.6759
# source چو با حاجب شاه گستاخ شد
# target پرستنده خسروی کاخ شد
# predicted SOS که و و و <EOS>
# source به پیش تو ایم کنون بی سپاه
# target ز تو بشنوم هرچ فرمود شاه
# predicted SOS که و و و <EOS>
# source نماند چنین دان جهان برکسی
# target درو شادکامی نیابی بسی
# predicted SOS که و و و <EOS>
# source خروشی برامد ز زابلستان
# target ز بدخواه وز شاه کابلستان
# predicted SOS که و و و <EOS>
# source همی بود تا بر چه گردد جهان
# target بدین اشکارا چه دارد نهان
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.970e+01 | Train PPL: 1.996e+43
# ended in:  68.34072208404541 sec
# num of iterations is 128
# 100 4.5658
# source سیاووش غمی گشت ز ایرانیان
# target سخن گفت بر پهلوانی زبان
# predicted SOS که و و و و <EOS>
# source چو ترکان بدیدند کارجاسپ رفت
# target همی اید از هر سوی تیغ تفت
# predicted SOS که و و و <EOS>
# source دل ما به بهرام ازان بود سرد
# target که از شاه بودیم یکسر به درد
# predicted SOS که و و و و <EOS>
# source نگه کرد و بنشاند اندر خورش
# target ز کاووس پرسید و از لشکرش
# predicted SOS که و و و و <EOS>
# source پذیرفتم از کردگار بلند
# target که گر تو به توران شوی بی گزند
# predicted SOS که و و و و <EOS>
# 	Train Loss: 9.792e+01 | Train PPL: 3.343e+42
# ended in:  68.64131498336792 sec
# num of iterations is 128
# 100 4.8480
# source بفرمود خسرو بسالار بار
# target که خوان از خورشگر کند خواستار
# predicted SOS که و و و <EOS>
# source چنان دان که نوشین روان قباد
# target به اندرز این کرد در نامه یاد
# predicted SOS که و و و <EOS>
# source بدین سان سپاهی بیامد ز گنگ
# target که خورشید را ارزو کرد جنگ
# predicted SOS که و و و <EOS>
# source گر او زین نپیچد سپهر بلند
# target کند اینک گفتم برو ارجمند
# predicted SOS که و و و <EOS>
# source نخستین به پیمان مرا شاد کن
# target ز سوگند شاهان یکی یاد کن
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.026e+02 | Train PPL: 3.548e+44
# ended in:  69.84770679473877 sec
# num of iterations is 128
# 100 4.8683
# source سپهدار کو ناشمرده سپاه
# target ستاره شمارد همی گرد ماه
# predicted SOS که و و و <EOS>
# source نوشته دران نامه شهریار
# target ز گردان و مردان نیزه گزار
# predicted SOS که و و و <EOS>
# source دو تا گشت پیران و بردش نماز
# target بسی افرین کرد و برگشت باز
# predicted SOS که و و و <EOS>
# source ابر افریننده کرد افرین
# target بمالید رخسارگان بر زمین
# predicted SOS که و و و <EOS>
# source تن خویش بینی همی در جهان
# target نه ای اگه از کارهای نهان
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.045e+02 | Train PPL: 2.461e+45
# ended in:  71.26326870918274 sec
# num of iterations is 128
# 100 4.6618
# source میان را به کین برادر ببند
# target ز فتراک مگشای بند کمند
# predicted SOS که و و و <EOS>
# source زچیز سیاوش نخستین کمر
# target بهرمهره ای در سه یاره گهر
# predicted SOS که و و و <EOS>
# source چو پاسخ بدان گونه دید اردشیر
# target سرش برتر امد ز ناهید و تیر
# predicted SOS که و و و <EOS>
# source همان رسم شاپور شاه اردشیر
# target همی داشت ان شاه دانش پذیر
# predicted SOS که و و و <EOS>
# source چنین گفت کاین را بگیرید زود
# target بپرسید زو تا که راهش نمود
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.872e+01 | Train PPL: 7.465e+42
# ended in:  71.08863353729248 sec
# num of iterations is 128
# 100 4.5804
# source به پیش اندرون پهلوانی سترگ
# target به جنگ اندرون هر یکی همچو گرگ
# predicted SOS که و و و <EOS>
# source هرانکس که تازانه دانست باز
# target برفتند و بردند پیشش نماز
# predicted SOS که و و و <EOS>
# source سپه را سراسر هم انجا بماند
# target خود و فیلسوفان رومی براند
# predicted SOS که و و و <EOS>
# source تژاو سپهبد بشد با سپاه
# target بایران خروش امد از دیده گاه
# predicted SOS که و و و <EOS>
# source برامد خروش از بر گاودم
# target دم نای سرغین و رویینه خم
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.788e+01 | Train PPL: 3.213e+42
# ended in:  71.34062457084656 sec
# num of iterations is 128
# 100 4.7028
# source نهانی روانش پر از درد بود
# target پر از خون دل و بخت برگرد بود
# predicted SOS که از از و <EOS>
# source یلان سینه راگفت کاین زن بشوی
# target چه گوید بجوید بدین اب روی
# predicted SOS که از از و <EOS>
# source که خاقان چین زینهاری شدست
# target ز جنگ درازم حصاری شدست
# predicted SOS که از از و <EOS>
# source که من چون رسیدم سواران چین
# target ورا کشته بودند بر دشت کین
# predicted SOS که از از و <EOS>
# source یکی رنج بردار و او راببین
# target سخنهای دانندگان برگزین
# predicted SOS که از از و <EOS>
# 	Train Loss: 1.002e+02 | Train PPL: 3.430e+43
# ended in:  70.98344779014587 sec
# num of iterations is 128
# 100 4.6839
# source سروی سر گاومیشی براست
# target همی این بران بر زدی چونک خواست
# predicted SOS که و و و <EOS>
# source کجا اورد دانش تو بها
# target چو ایی چنین در دم اژدها
# predicted SOS که و و و <EOS>
# source کسی مرد ازین سان به گیتی ندید
# target نه از نامداران پیشین شنید
# predicted SOS که و و و <EOS>
# source ز اورد گه شد سوی نهروان
# target همی بود بر پیش فرخ جوان
# predicted SOS که و و و <EOS>
# source بریزید خونش بران گرم خاک
# target ممانید دیر و مدارید باک
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.972e+01 | Train PPL: 2.039e+43
# ended in:  70.06493139266968 sec
# num of iterations is 128
# 100 4.6351
# source به یاران چنین گفت کاکنون گریز
# target به اید ز ارام با رستخیز
# predicted SOS که و و و <EOS>
# source گرامی یکی دخترش بود و بس
# target که نشمردی او دختران را به کس
# predicted SOS که و و و <EOS>
# source بنوی یکی باز پیمان نوشت
# target به باغ بزرگی درختی بکشت
# predicted SOS که و و و <EOS>
# source درفش فروزنده کاویان
# target بیفگنده باشند ایرانیان
# predicted SOS که و و و <EOS>
# source سپه را درم داد و اباد کرد
# target بهر کار با هر کسی داد کرد
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.930e+01 | Train PPL: 1.330e+43
# ended in:  70.17426562309265 sec
# num of iterations is 128
# 100 4.7301
# source چنین داد پاسخ که اری رواست
# target که تاج زمانه سر پادشاست
# predicted SOS که از و و <EOS>
# source چو بشنید گفتار سالار شاه
# target برافراخت تا ماه فرخ کلاه
# predicted SOS که از از و <EOS>
# source نباید که ایمن شوید از کمین
# target سپه باشد اندر در و دشت کین
# predicted SOS که از از و <EOS>
# source به زن گفت کژی و تاری مجوی
# target هرانچت بپرسم سخن راست گوی
# predicted SOS که از از و <EOS>
# source گرانمایگان پاسخ اراستند
# target همه یکسر از جای برخاستند
# predicted SOS که از و و <EOS>
# 	Train Loss: 1.009e+02 | Train PPL: 6.671e+43
# ended in:  69.87885880470276 sec
# num of iterations is 128
# 100 4.6574
# source بدانگه که لوح افرید و قلم
# target بزد بر همه بودنیها رقم
# predicted SOS که و و و <EOS>
# source چو خسرو بدان گونه اوا شنید
# target به رخساره شد چون گل شنبلید
# predicted SOS که و و و <EOS>
# source نباشد خرد جان نباشد رواست
# target خرد جان پاکست و ایزد گو است
# predicted SOS که و و و <EOS>
# source نخست افرین کرد بر شهریار
# target که شادان بزی تا بود روزگار
# predicted SOS که و و و <EOS>
# source چنین داد پاسخ یل اسفندیار
# target که لشکر نیاید مرا خود به کار
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.878e+01 | Train PPL: 7.910e+42
# ended in:  69.69569063186646 sec
# num of iterations is 128
# 100 4.6841
# source ازو دور گشتن به رغم هوا
# target خرد را بران رای کردن گوا
# predicted SOS که و و و <EOS>
# source پلاشان بدانست کامد سوار
# target بیامد بسیچیده کارزار
# predicted SOS که و و و <EOS>
# source فرستاد با او یکی نامدار
# target جوانوی شد تا در شهریار
# predicted SOS که و و و <EOS>
# source بیاورد ده جام گوهر ز گنج
# target بزر بافته جامه شاه پنج
# predicted SOS که و و و <EOS>
# source بر ان برنهادند یکسر که گیو
# target به زابل شود نزد سالار نیو
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.711e+01 | Train PPL: 1.492e+42
# ended in:  69.55190563201904 sec
# num of iterations is 128
# 100 4.5940
# source همی خورد افگنده مردار اوی
# target ز جامه برهنه تن خوار اوی
# predicted SOS که که و و <EOS>
# source نهادش به صندوق در نرم نرم
# target به چینی پرندش بپوشید گرم
# predicted SOS که که و و <EOS>
# source بکردار نخچیر در پیش من
# target کجات ان سپاه ای سر انجمن
# predicted SOS که که و و <EOS>
# source نبد کهتر از مهتران بر فرود
# target نشسته چنان چون بود تار و پود
# predicted SOS که که و و <EOS>
# source گر ایدونک با تو نجویند جنگ
# target برایشان مکن کار تاریک و تنگ
# predicted SOS که که و و <EOS>
# 	Train Loss: 9.907e+01 | Train PPL: 1.057e+43
# ended in:  69.82858324050903 sec
# num of iterations is 128
# 100 4.6501
# source نشست از بر تخت زرین او
# target بیفگند ناخوب ایین او
# predicted SOS که از و و <EOS>
# source یکی خامشی برگزین از میان
# target چوشد کندرو بخت ساسانیان
# predicted SOS که از و و <EOS>
# source که شاه افریدون بدوشاد بود
# target که ان تخت پرمایه ازاد بود
# predicted SOS که از و و <EOS>
# source سپهبد ز کوه اندر امد بده
# target ازان ده سبک پیش او رفت مه
# predicted SOS که از و و <EOS>
# source هیونی فرستاد نزدیک شاه
# target که لشکر برارای کامد سپاه
# predicted SOS که از و و <EOS>
# 	Train Loss: 9.857e+01 | Train PPL: 6.442e+42
# ended in:  70.47838091850281 sec
# num of iterations is 128
# 100 4.7051
# source نوشتند نامه بهر کشوری
# target سکوبا و بطریق و هر مهتری
# predicted SOS که و و و <EOS>
# source ستاره همی دامن ماه جست
# target پدر بر پسر بر همی راه جست
# predicted SOS که و و و <EOS>
# source گنهکار باشد تن زیردست
# target مگر مردم پاک و یزدان پرست
# predicted SOS که و و و <EOS>
# source فریدون چو گیتی بران گونه دید
# target جهان پیش ضحاک وارونه دید
# predicted SOS که و و و <EOS>
# source چونستود را دید بهرام گرد
# target عنان باره تیزتگ را سپرد
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.005e+02 | Train PPL: 4.366e+43
# ended in:  72.854811668396 sec
# num of iterations is 128
# 100 4.6734
# source که یک چند باشد بری مرزبان
# target یکی مرد بی دانش و بد زبان
# predicted SOS که و و و <EOS>
# source چو گرسیوز امد بران شهر نو
# target پذیره بیامد ز ایوان به کو
# predicted SOS که و و و <EOS>
# source چنین گفت زان پس به افراسیاب
# target که ای پرهنر شاه با جاه و اب
# predicted SOS که و و و <EOS>
# source چو دانی که بر تو نماند جهان
# target چه پیچی تو زان جای نوشین روان
# predicted SOS که و و و <EOS>
# source همی سبز در سبز خوانی کنون
# target برین گونه سازند مکر و فسون
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.918e+01 | Train PPL: 1.188e+43
# ended in:  72.93269157409668 sec
# num of iterations is 128
# 100 4.7134
# source فرستاده را پیش بنشاختند
# target ز هر در فراوانش بنواختند
# predicted SOS که و و و <EOS>
# source ابا خویشتن بر یکی پر من
# target خجسته بود سایه فر من
# predicted SOS که و و و <EOS>
# source برفتند سوی سیاووش گرد
# target پس پشت و پیش سپه بود گرد
# predicted SOS که و و و <EOS>
# source کسی را نداد از یلان زینهار
# target بکشتند زان خستگان بی شمار
# predicted SOS که و و و <EOS>
# source به میدان چوگان و بزم و شکار
# target گوی بود مانند اسفندیار
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.012e+02 | Train PPL: 8.575e+43
# ended in:  72.16049313545227 sec
# num of iterations is 128
# 100 4.7413
# source بزد دست و برداشتش نره شیر
# target به گردن براورد و افگند زیر
# predicted SOS که از و و <EOS>
# source یکی پاسخ نامه بنوشت و گفت
# target که با جان پاکان خرد باد جفت
# predicted SOS که از و و <EOS>
# source فرستاده با خلعت و کام خویش
# target ز در بازگشتی به ارام خویش
# predicted SOS که از و و <EOS>
# source غمی شد دل شیر در نیستان
# target ز خون نیستان کرد چون میستان
# predicted SOS که از و و <EOS>
# source نبد بر هوا مرغ را جایگاه
# target ز تیر و ز گرز و ز گرد سپاه
# predicted SOS که از و و <EOS>
# 	Train Loss: 1.011e+02 | Train PPL: 7.801e+43
# ended in:  73.34980320930481 sec
# num of iterations is 128
# 100 4.5475
# source در گنج بگشاد و دینار داد
# target از امروز و فردا نیامدش یاد
# predicted SOS که و و و <EOS>
# source برانم که گرد زمین اندکی
# target بگردم ببینم جهان را یکی
# predicted SOS که و و و <EOS>
# source گرانمایه لهراسپ ارام یافت
# target خرد مایه و کام پدرام یافت
# predicted SOS که از و و <EOS>
# source چنین گفت کز جنگ افراسیاب
# target نه ارام باید نه خورد و نه خواب
# predicted SOS که و و و <EOS>
# source برفتند با پند افراسیاب
# target برام پیر و جوان بر شتاب
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.666e+01 | Train PPL: 9.514e+41
# ended in:  73.18677091598511 sec
# num of iterations is 128
# 100 4.7277
# source وگر دشمنی دارد اندر نهان
# target بگوید بما شهریار جهان
# predicted SOS که و و و <EOS>
# source چو خواهی که ز ایدر شوی باز جای
# target زمانی نگویم بر من بپای
# predicted SOS که و و و <EOS>
# source چو با دانش ما ندارند تاو
# target نخواهند زین بوم و بر باژ و ساو
# predicted SOS که و و و <EOS>
# source نگاری بد اندر شبستان اوی
# target ز گلبرگ رخ داشت و ز مشک موی
# predicted SOS که و و و <EOS>
# source ترا بود باید همی پیشرو
# target که من رفتنی ام تو سالار نو
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.009e+02 | Train PPL: 6.904e+43
# ended in:  72.73620438575745 sec
# num of iterations is 128
# 100 4.6166
# source بدو گفت شاه از هنرها چه به
# target که گردد بدو مرد جوینده مه
# predicted SOS که و و و <EOS>
# source بران موبدان نامدار اردشیر
# target نوشته همی خواند ان چوب تیر
# predicted SOS که و و و <EOS>
# source بران سان که کیخسرو و کینه جوی
# target ترا بیش بود از کیان ابروی
# predicted SOS که و و و <EOS>
# source بهانه مرا نیز ازار اوست
# target نهانم پر از درد و تیمار اوست
# predicted SOS که و و و <EOS>
# source میان را ببستند با رومیان
# target گرفتند ناگاه تخت کیان
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.819e+01 | Train PPL: 4.379e+42
# ended in:  72.4854793548584 sec
# num of iterations is 128
# 100 4.8060
# source تو گفتی که با ما نگفت این سخن
# target نه سر بود ازان کار هرگز نه بن
# predicted SOS ز و و و و <EOS>
# source ببرد سران گرازان بتیغ
# target ندارم ازو گنج گوهر دریغ
# predicted SOS ز و و و و <EOS>
# source چنین داد پاسخ که از اگهی
# target فراوان بود کژ ومغزش تهی
# predicted SOS ز و و و و <EOS>
# source خردمند بنشست با رای زن
# target بپالود زایوان شاه انجمن
# predicted SOS ز و و و و <EOS>
# source ز گیتی ستایش مر او را کنید
# target شب اید نیایش مر او را کنید
# predicted SOS ز و و و و <EOS>
# 	Train Loss: 1.050e+02 | Train PPL: 3.839e+45
# ended in:  76.2642765045166 sec
# num of iterations is 128
# 100 4.6374
# source ستایش کنان پیش او شد بدرد
# target هم این داستان سربسر یاد کرد
# predicted SOS ز و و و <EOS>
# source وزان روی طلخند پیش سپاه
# target چنین گفت با پاسبانان گاه
# predicted SOS ز و و و <EOS>
# source همی بود ترسان ز ازار شاه
# target جهاندار پر خشم و او بیگناه
# predicted SOS ز و و و <EOS>
# source ز اسپ اندرامد گو نامدار
# target از ایران بپرسید وز شهریار
# predicted SOS ز و و و <EOS>
# source برزمی که کردی چنین کش مشو
# target هنرمند بودی منی فش مشو
# predicted SOS ز و و و <EOS>
# 	Train Loss: 1.002e+02 | Train PPL: 3.440e+43
# ended in:  74.13177561759949 sec
# num of iterations is 128
# 100 4.8675
# source بگفت این و برخاست از پیش او
# target چو اگاه گشت از کم و بیش او
# predicted SOS که و و و <EOS>
# source چواتش که گوگرد یابد خورش
# target گرش درنیستان بود پرورش
# predicted SOS که و و و و <EOS>
# source نشستند با رودسازان به هم
# target بدان تا تهمتن نباشد دژم
# predicted SOS که و و و و <EOS>
# source چنانچون ببایست برساختند
# target ز هر سو طلایه برون تاختند
# predicted SOS که و و و و <EOS>
# source سیاوش ازان کار بد بی گناه
# target خردمندی وی بدانست شاه
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.034e+02 | Train PPL: 7.700e+44
# ended in:  75.122318983078 sec
# num of iterations is 128
# 100 4.6672
# source سخن چون ز تنگی به سختی رسید
# target فراخیش را زود بینی کلید
# predicted SOS که و و و <EOS>
# source پرستنده و تاج شاهان و مهد
# target هم ان را که خوردی ازو شیر و شهد
# predicted SOS که و و و <EOS>
# source ز پیران مرا دل بسوزد همی
# target ز مهرش روان برفروزد همی
# predicted SOS که و و و <EOS>
# source به خیره همی جنگ فرمایدم
# target بترسم که سوگند بگزایدم
# predicted SOS که و و و <EOS>
# source به یالش همی اندراویختند
# target همی خاک بر تارکش ریختند
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.820e+01 | Train PPL: 4.450e+42
# ended in:  76.70796465873718 sec
# num of iterations is 128
# 100 4.6937
# source ز شاه کیان چشم بد دور باد
# target روان سیاوش پر از نور باد
# predicted SOS که و و و <EOS>
# source بیامد یکی پیر مهتر فریب
# target ترا دل پر از بیم کرد و نهیب
# predicted SOS که و و و <EOS>
# source بزرگان چو گودرز کشوادگان
# target چو گیو و چو رهام ز ازادگان
# predicted SOS که و و و <EOS>
# source نبیره که کین نیا را نجست
# target سزد گر نخوانی نژادش درست
# predicted SOS که و و و <EOS>
# source مگر دیو با او هم اواز گشت
# target که از راه یزدان سرش بازگشت
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.986e+01 | Train PPL: 2.344e+43
# ended in:  74.98346614837646 sec
# num of iterations is 128
# 100 4.6987
# source بدانگه کجا بانگ و ویله کنند
# target تو گویی همی کوه را برکنند
# predicted SOS که از بر و <EOS>
# source که با اهوان گفت غرم ژیان
# target که گر دشت گردد همه پرنیان
# predicted SOS که از بر و <EOS>
# source کجا اوفتادست گفتی زریر
# target پدر ان نبرده سوار دلیر
# predicted SOS که از بر و <EOS>
# source کسی زین نشان هیچ برنگذرد
# target کزان رود برتر زمین نشمرد
# predicted SOS که از از و <EOS>
# source چو پوینده نزدیک دستان رسید
# target بگفت انچ دانست و دید و شنید
# predicted SOS که از بر و <EOS>
# 	Train Loss: 1.002e+02 | Train PPL: 3.298e+43
# ended in:  73.70946264266968 sec
# num of iterations is 128
# 100 4.6823
# source هرانکس که جست از یلان نام را
# target سپهبد همی خواند بهرام را
# predicted SOS که و و و <EOS>
# source بترسید پس مرد بیدار دل
# target کجا بسته بود اندران کار دل
# predicted SOS که و و و <EOS>
# source ز پیش طلایه سواری چو گرد
# target بیامد سخنها همه یاد کرد
# predicted SOS که و و و <EOS>
# source پدر شاه و فرزانه تر پادشاست
# target بدیت راست گفتار من بر گواست
# predicted SOS که و و و <EOS>
# source سر و نام برزین براید به ماه
# target اگر شاد گردد بدین باغ شاه
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.006e+02 | Train PPL: 4.847e+43
# ended in:  74.12730860710144 sec
# num of iterations is 128
# 100 4.8966
# source ابوالقاسم ان شهریار دلیر
# target کجا گور بستاند از چنگ شیر
# predicted SOS که و و و <EOS>
# source بپرسید کز شهریاران که بیش
# target بهوش و به ایین و با رای و کیش
# predicted SOS که و و و <EOS>
# source همان ارزوها بیفزایدت
# target چو افزون خوری چیز نگزایدت
# predicted SOS که و و و <EOS>
# source بدو گفت کاین دانشم نیز هست
# target چو گویی بسایم برین کاردست
# predicted SOS که و و و <EOS>
# source دلم شادمان شد ز پولادوند
# target که بفزود بر بند پولاد بند
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.033e+02 | Train PPL: 7.470e+44
# ended in:  74.49466800689697 sec
# num of iterations is 128
# 100 4.7370
# source بدو گفت خسرو نژاد تو چیست
# target که چهرت همانند چهر پریست
# predicted SOS که و و و <EOS>
# source گریزان سپهرم بدان روی اب
# target بشدبا سپه نزد افراسیاب
# predicted SOS که و و و <EOS>
# source چنان امدم شهریارا گمان
# target کزو کوه زنهار خواهد بجان
# predicted SOS که و و و <EOS>
# source خورش هست و ایوان و گنج و سپاه
# target ترا رنج بدخواه را تاج و گاه
# predicted SOS که و و و <EOS>
# source همی خورد می تا جهان تیره شد
# target سرمیگساران ز می خیره شد
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.002e+02 | Train PPL: 3.276e+43
# ended in:  73.42001533508301 sec
# num of iterations is 128
# 100 4.6889
# source براسود پس لشکر از هر دو روی
# target برفتند روز دوم جنگجوی
# predicted SOS که و و و <EOS>
# source کدیور بدو گفت کز کردگار
# target سراید مگر بر من این روزگار
# predicted SOS که و و و <EOS>
# source بگو ان دو بی شرم ناپاک را
# target دو بیداد و بد مهر و ناباک را
# predicted SOS که و و و <EOS>
# source ببینی کنون بارگاه بزرگ
# target جهانی جدا کرده از میش گرگ
# predicted SOS که و و و <EOS>
# source پر از درد دیدم دل پارسا
# target که اندر جهان دیو بد پادشا
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.004e+02 | Train PPL: 4.132e+43
# ended in:  74.06603622436523 sec
# num of iterations is 128
# 100 4.6093
# source بدو گفت گوینده بوزرجمهر
# target که ای موبد رای خورشید چهر
# predicted SOS که و و و <EOS>
# source شگفت ار بمانی بدین در رواست
# target هرانکس که او بر جهان پادشاست
# predicted SOS که و و و <EOS>
# source یکی لشکر از کوه تا کوه مرد
# target زمین قیرگون و هوا لاژورد
# predicted SOS که و و و <EOS>
# source جهان را فزوده بدو ابروی
# target فروزان شده تخت شاهی بدوی
# predicted SOS که و و و <EOS>
# source چو ان نامه شاه بابک بخواند
# target بسی خون مژگان به رخ برفشاند
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.792e+01 | Train PPL: 3.359e+42
# ended in:  73.84867525100708 sec
# num of iterations is 128
# 100 4.6399
# source ازان شادمان گشت فرخنده شاه
# target دلش خیره امد زبی مر سپاه
# predicted SOS که و و و <EOS>
# source بفرمای تا رخش را همچنان
# target بیارند پیش من اندر زمان
# predicted SOS که و و و <EOS>
# source بدو گفت بهرام پس چاره کن
# target وزین راز مگشای بر کس سخن
# predicted SOS که و و و <EOS>
# source دولشکر کشیدند صف بر دو میل
# target دو شاه سرافراز بر پشت پیل
# predicted SOS که و و و <EOS>
# source ز یزدان همی ارزو خواستم
# target که اکنون بتو دل بیاراستم
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.741e+01 | Train PPL: 2.013e+42
# ended in:  74.2893226146698 sec
# num of iterations is 128
# 100 4.6322
# source به توران و ایران چنو نیو کیست
# target چنین خام گفتارت از بهر چیست
# predicted SOS که و و و <EOS>
# source فریبرز نزدیک خسرو رسید
# target زمین را ببوسید کو را بدید
# predicted SOS که و و و <EOS>
# source گذشتند بر اب بر هفت ماه
# target که بادی نکرد اندریشان نگاه
# predicted SOS که و و و <EOS>
# source بفرمود تاموبد و رای زن
# target برفتند با نامدار انجمن
# predicted SOS که و و و <EOS>
# source سخن گفتن موبدان گوهرست
# target مرا در دل اندیشه دیگرست
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.812e+01 | Train PPL: 4.104e+42
# ended in:  76.11130142211914 sec
# num of iterations is 128
# 100 4.5241
# source چو کاووس لشکر به خشکی کشید
# target کس اندر جهان کوه و صحرا ندید
# predicted SOS که و و و <EOS>
# source مبادا که گیرد به نزد تو جای
# target چنین مرد گر باشدت رهنمای
# predicted SOS که و و و <EOS>
# source فرود امد و پیش یزدان بخاک
# target بغلتید و گفت ای جهاندار پاک
# predicted SOS که و و و <EOS>
# source نگه کرد بهرام زان قلب گاه
# target گریزان سپه دید پیش سپاه
# predicted SOS که و و و <EOS>
# source بینداخت الکوس گرزی چو کوه
# target که از بیم او شد زواره ستوه
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.659e+01 | Train PPL: 8.896e+41
# ended in:  74.31267166137695 sec
# num of iterations is 128
# 100 4.5423
# source که گودرز و گیو اندر امد بجنگ
# target سپه باید ایدر مرا بی درنگ
# predicted SOS ز و و و <EOS>
# source بدان دختران رد افراسیاب
# target نگه کرد کاوس مژگان پر اب
# predicted SOS ز و و و <EOS>
# source وزان پس که شد سوی هاماوران
# target ببستند پایش به بند گران
# predicted SOS ز و و و <EOS>
# source سخن هر چه زین گوهران بگذرد
# target نیابد بدو راه جان و خرد
# predicted SOS ز و و و <EOS>
# source ترا خواهم اندر جهان نیکوی
# target بزرگی و پیروزی و خسروی
# predicted SOS ز و و و <EOS>
# 	Train Loss: 9.543e+01 | Train PPL: 2.778e+41
# ended in:  75.22083282470703 sec
# num of iterations is 128
# 100 4.8249
# source بیا تا به کشتی پیاده شویم
# target ز خوی هر دو اهار داده شویم
# predicted SOS که و و و <EOS>
# source چنین بود تا بیست و سه ساله گشت
# target به جام اندرون باده چون لاله گشت
# predicted SOS که و و و <EOS>
# source زند بر در شهر خوارزم گاه
# target ابا شیده رزم زن کینه خواه
# predicted SOS که و و و <EOS>
# source چو تیر اسپری شد سوی نیزه گشت
# target چو دریای خون شد همه کوه و دشت
# predicted SOS که و و و <EOS>
# source دو منزل یکی کرد و امد دوان
# target همی تاخت برسان تیر از کمان
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.949e+01 | Train PPL: 1.622e+43
# ended in:  75.93645644187927 sec
# num of iterations is 128
# 100 4.6995
# source سپاهی بیاورد بهرام گرد
# target که از اسمان روشنایی ببرد
# predicted SOS که و و و <EOS>
# source دمادم شما از پسم بگذرید
# target بجیحون و زورق زمان مشمرید
# predicted SOS که و و و <EOS>
# source همه نامداران به فرمان اوی
# target سوی سرو کشمر نهادند روی
# predicted SOS که و و و <EOS>
# source خروشیدن تازی اسپان ز دشت
# target ز بانگ تبیره همی برگذشت
# predicted SOS که و و و <EOS>
# source هرانکس که رفتی که چیزی برد
# target وگر خاک ان خانه را بسپرد
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.005e+02 | Train PPL: 4.294e+43
# ended in:  76.24863243103027 sec
# num of iterations is 128
# 100 4.8083
# source و گر نیستت اگهی زان گناه
# target برهنه دلت را ببر نزد شاه
# predicted SOS که از و و <EOS>
# source برادر بد از کالبد هم ز پشت
# target چنان پرخرد بیگنه را بکشت
# predicted SOS که از و و <EOS>
# source به شاهی برو افرین خواند زال
# target نشست از بر تخت زو پنج سال
# predicted SOS که از و و <EOS>
# source سپهر اندران رزمگه خیره شد
# target ز گرد سپه چشمها تیره شد
# predicted SOS که از و و <EOS>
# source سرافراز کیخسروش نام کن
# target به غم خوردن او دل ارام کن
# predicted SOS که از و و <EOS>
# 	Train Loss: 1.027e+02 | Train PPL: 4.125e+44
# ended in:  76.16185784339905 sec
# num of iterations is 128
# 100 4.6258
# source تو این اندکی لشکر من مبین
# target مراجوی با گرز بر پشت زین
# predicted SOS که از و و <EOS>
# source ولیکن چو بهرم راند سپاه
# target نماید خردمند را رای و راه
# predicted SOS که و و و <EOS>
# source چنان خواست روشن جهان افرین
# target که اونیست گردد به ایران زمین
# predicted SOS که از و و <EOS>
# source درشتی کنم زین سخن ماه چند
# target که پیدا شود داد و مهر از گزند
# predicted SOS که از و و <EOS>
# source بدو گفت سالار لشکر تویی
# target بتو باز گردد بد و نیکویی
# predicted SOS که از و و <EOS>
# 	Train Loss: 9.968e+01 | Train PPL: 1.956e+43
# ended in:  76.67553997039795 sec
# num of iterations is 128
# 100 4.6296
# source جهاندار نیک اختر و راه جوری
# target برفت از لب اب با اب روی
# predicted SOS که از و و <EOS>
# source کجا کارشان همگنان پیشه بود
# target روانشان همیشه پراندیشه بود
# predicted SOS که از و و <EOS>
# source به پنجم سخن مردم زشت گوی
# target نگیرد به نزد کسان اب روی
# predicted SOS که و و و <EOS>
# source به چنگال می کرد منقار تیز
# target چو ایمن شد از گردش رستخیز
# predicted SOS که از و و <EOS>
# source من ان ایزدی فره باز اورم
# target جهان را به مهرش نیاز اورم
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.959e+01 | Train PPL: 1.779e+43
# ended in:  76.73104619979858 sec
# num of iterations is 128
# 100 4.6688
# source که از تو نه این بد سزاوار اوی
# target برو کینش از دشمنان بازجوی
# predicted SOS به و و و <EOS>
# source همه جامه اش سبز و خنگی به زیر
# target ز دیدار او گشت خسرو دلیر
# predicted SOS به و و و <EOS>
# source از ایشان جز او دخت خاتون نبود
# target به پیرایه و رنگ وافسون نبود
# predicted SOS به و و و <EOS>
# source تو فرزندی و شاه ایران توی
# target برزم اندرون چنگ شیران توی
# predicted SOS به و و و <EOS>
# source کسی را کجا فر یزدان نبود
# target وگر اختر نیک خندان نبود
# predicted SOS به و و و <EOS>
# 	Train Loss: 9.899e+01 | Train PPL: 9.820e+42
# ended in:  76.19656252861023 sec
# num of iterations is 128
# 100 4.6830
# source بپرسیدش از کژی و راه دیو
# target ز راه جهاندار کیهان خدیو
# predicted SOS ز و و و <EOS>
# source نبودی جدا یک زمان ز اردشیر
# target ورا همچو دستور بودی وزیر
# predicted SOS ز و و و <EOS>
# source نگهبان دژ رزم دیده هجیر
# target که با زور و دل بود و با دار و گیر
# predicted SOS ز و و و <EOS>
# source ز گرد سپه پیل شد ناپدید
# target کس از خاک دست و عنان را ندید
# predicted SOS ز و و و <EOS>
# source به در بر همه فرش دیبا کشید
# target بیامد به قیصر بگفت انچ دید
# predicted SOS ز و و و <EOS>
# 	Train Loss: 1.002e+02 | Train PPL: 3.188e+43
# ended in:  77.95457816123962 sec
# num of iterations is 128
# 100 4.6765
# source زمین شد به کردار دریای قیر
# target همه موجش از خنجر و گرز و تیر
# predicted SOS که از و و <EOS>
# source وزان زخم مردان کجا می زنند
# target و بر یکدگر بر همی افگند
# predicted SOS که و و و <EOS>
# source بدانگه که خورشید برگشت زرد
# target بگسترد شب چادر لاژورد
# predicted SOS که و و و <EOS>
# source بر شاه رو گفت و او را بگوی
# target که ز اهرمن اکنون بهانه مجوی
# predicted SOS که و و و <EOS>
# source درنگ اوری کار گردد تباه
# target میاسا و اسپ درنگی مخواه
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.861e+01 | Train PPL: 6.697e+42
# ended in:  77.96646451950073 sec
# num of iterations is 128
# 100 4.7219
# source ز گفتار مرد ستاره شمر
# target دلش بود پر درد و پیچان جگر
# predicted SOS که از و و <EOS>
# source چنین باکسی گفت باید که گنج
# target نبیند نه لشکر نه رزم و نه رنج
# predicted SOS که از و و <EOS>
# source خنک شاه گشتاسپ ان نامدار
# target کجا پور دارد چو اسفندیار
# predicted SOS که از و و <EOS>
# source هیونان و بالا وپیل سپید
# target همه گشته از جان تو ناامید
# predicted SOS که از و و <EOS>
# source بباید زدن دشنه ای بر برش
# target وگر تیغ هندی یکی بر سرش
# predicted SOS که از و و و <EOS>
# 	Train Loss: 1.005e+02 | Train PPL: 4.408e+43
# ended in:  77.41263365745544 sec
# num of iterations is 128
# 100 4.8139
# source تژاو ان زمان با پرستنده گفت
# target که دشوار کار امد ای خوب جفت
# predicted SOS که و و و <EOS>
# source توزین هرچ کاری پسر بدرود
# target زمانه زمانی همی نغنود
# predicted SOS که و و و <EOS>
# source به بیداد ماند همی داد شاه
# target منه پند گفتار من بر گناه
# predicted SOS که و و و <EOS>
# source پشوتن برین بر گوای منست
# target روان و خرد رهنمای منست
# predicted SOS که و و و <EOS>
# source چو این مرد چاکر باندک سپاه
# target ز جایی بیاید به درگاه شاه
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.021e+02 | Train PPL: 2.135e+44
# ended in:  78.5108368396759 sec
# num of iterations is 128
# 100 4.7074
# source ز شاهان هرانکس که بد پیش ازوی
# target اگر کم بدش گاه اگر بیش ازوی
# predicted SOS که و و و <EOS>
# source جز از تو زبر داوری دیگرست
# target کز اندیشه برتران برترست
# predicted SOS که و و و <EOS>
# source چو ارجاسپ بشنید گفتار دیو
# target فرود امد از گاه گیهان خدیو
# predicted SOS که و و و <EOS>
# source کسی کو ز فرزند او نام برد
# target چنین گفت کان پاک زاده بمرد
# predicted SOS که و و و <EOS>
# source جهاندار بگرفت و از نهان
# target به زمزم همی رای زد با مهان
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.013e+02 | Train PPL: 1.001e+44
# ended in:  78.36277437210083 sec
# num of iterations is 128
# 100 4.8737
# source ربودند ایرانیان گوی پیش
# target بماندند ترکان ز کردار خویش
# predicted SOS که و و و <EOS>
# source چو لشکر بدانست کاسفندیار
# target ز بند گران رست و بد روزگار
# predicted SOS که و و و <EOS>
# source چو بی رنج دشمن بچنگ ایدت
# target چو بشتابیش کار تنگ ایدت
# predicted SOS که و و و <EOS>
# ...
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.013e+02 | Train PPL: 1.014e+44
# ended in:  85.95807003974915 sec
# num of iterations is 128
# 100 4.7322
# source تو چون غرم رفتستی اندر کمر
# target پر از داوری دل پر از کینه سر
# predicted SOS که و و و <EOS>
# source یکی بنده ام با تنی پرگناه
# target به پیش خداوند خورشید و ماه
# predicted SOS که و و و <EOS>
# source کسی کو به خلعت سزاوار بود
# target خردمند بود و جهاندار بود
# predicted SOS که و و و <EOS>
# source نه پیوند و فرزند و تخت و کلاه
# target نه دیهیم شاهی نه گنج و سپاه
# predicted SOS که و و و <EOS>
# source نباید که اندیشه شهریار
# target بود جز پسندیده کردگار
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.029e+02 | Train PPL: 5.022e+44
# ended in:  84.24370861053467 sec
# num of iterations is 128
# 100 4.7204
# source کنون این زره چون زمین منست
# target سپر اسمان زرین منست
# predicted SOS که از و و <EOS>
# source بدانست کش کار دشوار گشت
# target جهان تیره شد بخت او خوار گشت
# predicted SOS که از و و <EOS>
# source تو از جنگ پیران مبر تاب روی
# target سپه را بیارای و زو کینه جوی
# predicted SOS که از و و <EOS>
# source به بیداد برنیست این کار تو
# target بسندست یزدان نگهدار تو
# predicted SOS که از و و <EOS>
# source از اندیشه دل نیامدش خواب
# target به رزم و به بزمش گرفته شتاب
# predicted SOS که از و و <EOS>
# 	Train Loss: 1.005e+02 | Train PPL: 4.639e+43
# ended in:  84.7868480682373 sec
# num of iterations is 128
# 100 4.8619
# source تو با شاه برشو به بالای تند
# target ز پیران و لشکر مشو هیچ کند
# predicted SOS که و و و <EOS>
# source کسی را جز از تو نخواهند شاه
# target که زیبای تاجی و زیبای گاه
# predicted SOS که و و و <EOS>
# source وزان پس ز ارام سردی نمود
# target ز سردی همان باز تری فزود
# predicted SOS که و و و <EOS>
# source چو نیرو کند با سرو یال و شاخ
# target پدر پیر گشته نشسته به کاخ
# predicted SOS که و و و <EOS>
# source کشیدند می تا جهان تیره گشت
# target سرمیگساران ز می خیره گشت
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.036e+02 | Train PPL: 1.025e+45
# ended in:  87.22324681282043 sec
# num of iterations is 128
# 100 4.7690
# source وگر کژی ارد بداد اندرون
# target کبستش بود خوردن و اب خون
# predicted SOS که و و و <EOS>
# source سخن چند گفتم به چندین نشست
# target ز گفتار باد است ما را به دست
# predicted SOS که و و و <EOS>
# source چو بشنید ماهوی بیدادگر
# target سخنها کجا گفت او را پسر
# predicted SOS که و و و <EOS>
# source تو اکنون سوی بارگی دار دست
# target دل شاه ایران نشاید شکست
# predicted SOS که و و و <EOS>
# source ز بس غارت و کشتن مرد و زن
# target پراگنده گشت ان بزرگ انجمن
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.004e+02 | Train PPL: 4.113e+43
# ended in:  83.27988982200623 sec
# num of iterations is 128
# 100 4.6328
# source سر مایه کرد اهن ابگون
# target کزان سنگ خارا کشیدش برون
# predicted SOS که و و و <EOS>
# source به جوش امد ان نامبردار گرد
# target عنان باره تیزتگ را سپرد
# predicted SOS که و و و <EOS>
# source چو بهرام گور ان شترمرغ دید
# target به کردار باد هوا بردمید
# predicted SOS که و و و <EOS>
# source چو بر خوان نشستی ورا خواندی
# target بر نامدارانش بنشاندی
# predicted SOS که و و و <EOS>
# source جهاندار خسرو گرفتش ببر
# target که ای دست مردی و جان هنر
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.994e+01 | Train PPL: 2.537e+43
# ended in:  86.38812923431396 sec
# num of iterations is 128
# 100 4.7022
# source همی نیزه بر مغفر ابدار
# target نیامد به زخم اندرون پایدار
# predicted SOS که و و و <EOS>
# source بدو گفت رستم که چنگال شیر
# target نپیموده ای زان شدستی دلیر
# predicted SOS که و و و <EOS>
# source خود و گرد مهراب کابل خدای
# target پذیره شدن را نهادند رای
# predicted SOS که و و و <EOS>
# source چو نزدیک شد روی دارا بدید
# target پر از خون بر و روی چون شنبلید
# predicted SOS که و و و <EOS>
# source سر از رزم و از رنج و کین خواستن
# target براسود وز لشکر اراستن
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.024e+02 | Train PPL: 2.829e+44
# ended in:  89.71599411964417 sec
# num of iterations is 128
# 100 4.6971
# source پس اگاهی امد به سالار چین
# target که شاه از گمان اندرامد به کین
# predicted SOS که و و و <EOS>
# source کنون از گروگان کی اندیشد او
# target همان پیش چشمش همان خاک کو
# predicted SOS که و و و <EOS>
# source ششم هرکه امد ز راه دراز
# target همی داشت درویشی خویش راز
# predicted SOS که و و و <EOS>
# source یکی جای خویش فرود اورید
# target به کف بر گرفتند هر دو نبید
# predicted SOS که و و و <EOS>
# source زمانه برامد به هفتم سخن
# target فگندی وفا را بسوگند بن
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.943e+01 | Train PPL: 1.520e+43
# ended in:  85.1416540145874 sec
# num of iterations is 128
# 100 4.6673
# source خردمندی و پیش بینی کنی
# target توانایی و پاک دینی کنی
# predicted SOS که و و و <EOS>
# source فرومانده اسبان جنگی بجای
# target تو گفتی که با دست بستست پای
# predicted SOS که و و و <EOS>
# source گشاده بفرمود تا گرگسار
# target بیامد به پیش یل اسفندیار
# predicted SOS که و و و <EOS>
# source مرا بارگیر اینک جوشن کشد
# target دو ماندست اگر زین یکی را کشد
# predicted SOS که و و و <EOS>
# source سرش تنگ بگرفت و یک پوشه چاک
# target بداد و نبود اگه از شرم و باک
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.780e+01 | Train PPL: 2.969e+42
# ended in:  82.43833065032959 sec
# num of iterations is 128
# 100 4.7030
# source بران تخت سودابه ماه روی
# target بسان بهشتی پر از رنگ و بوی
# predicted SOS که و و و <EOS>
# source نیامد ز لشکر ترا یار کس
# target وزیشان نبینمت فریادرس
# predicted SOS که و و و <EOS>
# source خرد بادل روشن انباز کرد
# target به اندیشه بنهاد برتخت نرد
# predicted SOS که و و و <EOS>
# source فرستاده قیصر سقف را بخواند
# target بپرسید و بر تخت زرین نشاند
# predicted SOS که و و و <EOS>
# source همی کرد هر کس به خسرو نگاه
# target همه انجمن خیره از بیم شاه
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.799e+01 | Train PPL: 3.605e+42
# ended in:  78.1904993057251 sec
# num of iterations is 128
# 100 4.9134
# source یکی رزمگاهی بیاراستند
# target یلان هم نبردان همی خواستند
# predicted SOS که و و و <EOS>
# source که مردی ز گردنکشان روز جنگ
# target به چنگال او خاک شد بی درنگ
# predicted SOS که و و و <EOS>
# source ترا بر سپه کامگاری دهم
# target به هندوستان شهریاری دهم
# predicted SOS که و و و <EOS>
# source درامد چو باد اشکش از دست راست
# target ز گرسیوز تیغ زن کینه خواست
# predicted SOS که و و و <EOS>
# source بسی تخت شاهان بپرداختی
# target سرت را به گردون برافراختی
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.053e+02 | Train PPL: 5.641e+45
# ended in:  81.19265723228455 sec
# num of iterations is 128
# 100 4.7622
# source شب و روز ماسای و سر بر مخار
# target ببر نامه من بر شهریار
# predicted SOS که و و و <EOS>
# source بسی رنج دارد به جای سران
# target جهان راست کرده به گرز گران
# predicted SOS که و و و <EOS>
# source ز تخت بلندی به اسپ اندر ای
# target مزن رای با موبد و رهنمای
# predicted SOS که و و و <EOS>
# source چنین لشکری گشن ما را که هست
# target برین تنگ دژها نشاید نشست
# predicted SOS که و و و <EOS>
# source بدو گفت گودرز کای شهریار
# target سخنها درازست زین کارزار
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.017e+02 | Train PPL: 1.461e+44
# ended in:  81.82186627388 sec
# num of iterations is 128
# 100 4.6400
# source بدین مایه لشکر تو تندی مجوی
# target بتندی بپیش دلیران مپوی
# predicted SOS که و و و <EOS>
# source فرود امد از بارگی شاه نرم
# target بدان تاکند برگیا چشم گرم
# predicted SOS که و و و <EOS>
# source ببینید تا از شما ریز کیست
# target که بر جان بدبخت باید گریست
# predicted SOS که و و و <EOS>
# source بزد بر سر خسرو تاجدار
# target ازو خواست ایرج به جان زینهار
# predicted SOS که و و و <EOS>
# source تگرگ امدی امسال برسان مرگ
# target مرا مگر بهتر بدی از تگرگ
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.884e+01 | Train PPL: 8.440e+42
# ended in:  82.492849111557 sec
# num of iterations is 128
# 100 4.6473
# source کنون جفت من باش تا برخوری
# target بدان تا سوی کهتری ننگری
# predicted SOS که از و و <EOS>
# source به خورشید رویان جهاندار گفت
# target که چونین شگفتی بشاید نهفت
# predicted SOS که از و و <EOS>
# source که بسیاردان است و چیره زبان
# target هشیوار و بینادل و بدگمان
# predicted SOS که از و و <EOS>
# source دگرانک روزش بباید شمرد
# target به کار بزرگ اندرون دست برد
# predicted SOS که از و و <EOS>
# source ازان لشکر روم چندان بکشت
# target که گفتی فلک تیغ دارد به مشت
# predicted SOS که از و و <EOS>
# 	Train Loss: 1.008e+02 | Train PPL: 5.958e+43
# ended in:  82.00161457061768 sec
# num of iterations is 128
# 100 4.7564
# source پر از ارزو دل لبان پر ز باد
# target همی داشت گفتار ایشان به یاد
# predicted SOS که و و و <EOS>
# source یکی زن نگه کن سزاوار خویش
# target از ایران منه درد و تیمار پیش
# predicted SOS که و و و <EOS>
# source ز درگه یکی چاره گر برگزید
# target سخن دان و گویا چناچون سزید
# predicted SOS که و و و <EOS>
# source همان گونه اب را تیره دید
# target پرستنده را دیدگان خیره دید
# predicted SOS که و و و <EOS>
# source چنان افریند که ایدش رای
# target نمانیم و ماندیم با های های
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.008e+02 | Train PPL: 6.132e+43
# ended in:  84.89487028121948 sec
# num of iterations is 128
# 100 4.8819
# source بمن بخشد او را جهاندار شاه
# target بدان تاکنون با من اید به راه
# predicted SOS که و و و <EOS>
# source نبیند چو تو نیز خورشید و ماه
# target نه جوشن نه تخت و نه تاج و کلاه
# predicted SOS که و و و <EOS>
# source سر سنجه را ناگه از تن بکند
# target خروشش برامد بابر بلند
# predicted SOS که و و و <EOS>
# source کس از ازمایش نیابد جواز
# target نشیب ایدش چون شود بر فراز
# predicted SOS که و و و <EOS>
# source بمردی نیابد کسی زو رها
# target چنین امد این تیزچنگ اژدها
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.047e+02 | Train PPL: 3.007e+45
# ended in:  80.58133149147034 sec
# num of iterations is 128
# 100 4.8223
# source بباشیم تا زین سخن نزد شاه
# target شود اشکارا ز گرگین گناه
# predicted SOS به و و و <EOS>
# source بدو گفت بهرام سالار طوس
# target که با اختر کاویانست و کوس
# predicted SOS به و و و <EOS>
# source بگیو ان زمان گفت برکش سپاه
# target برین دشت زین بیش دشمن مخواه
# predicted SOS به و و و <EOS>
# source بداند که بر عرض ازرم نیست
# target سخن با محابا و با شرم نیست
# predicted SOS به و و و <EOS>
# source همه رزمگه کشته چون کوه کوه
# target به هم برفگنده ز هر دو گروه
# predicted SOS به و و و <EOS>
# 	Train Loss: 1.019e+02 | Train PPL: 1.728e+44
# ended in:  79.77821326255798 sec
# num of iterations is 128
# 100 4.6541
# source ز توران سوی زابلستان کشید
# target به نزدیک فرخنده دستان کشید
# predicted SOS که و و و <EOS>
# source گر اندیشه بد کنی بد رسد
# target چه باید به شاهان چنین گشت بد
# predicted SOS که و و و <EOS>
# source پس اگاه کردند زان کارزار
# target پس شاه را فرخ اسفندیار
# predicted SOS که و و و <EOS>
# source بدو گفت پیمانت خواهم نخست
# target به چاره دلش را ز کینه بشست
# predicted SOS که و و و <EOS>
# source بسیمرغ بادا هزار افرین
# target که ایزد ورا ره نمود اندرین
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.003e+02 | Train PPL: 3.651e+43
# ended in:  80.48814654350281 sec
# num of iterations is 128
# 100 4.6857
# source ازان پس یکی کوه بینی بلند
# target که بالای او برتر از چون و چند
# predicted SOS که و و و <EOS>
# source همی باز جستند راز سپهر
# target بصلاب تا بر که گردد بمهر
# predicted SOS که و و و <EOS>
# source سه خواهر ز یک مادر و یک پدر
# target پری چهره و پاک و خسرو گهر
# predicted SOS که و و و <EOS>
# source برفتند از جای یکسر چو کوه
# target دهاده برامد ز هر دو گروه
# predicted SOS که و و و <EOS>
# source به پیکار مندیش ز افراسیاب
# target بجای ارد دل روی ازو برمتاب
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.001e+02 | Train PPL: 2.987e+43
# ended in:  79.54123044013977 sec
# num of iterations is 128
# 100 4.6882
# source تو توران نگه دار و تخت بلند
# target ز ایران کنون نیست بیم گزند
# predicted SOS که و و و <EOS>
# source ز تیزی روانش مدارا گزید
# target دلش رای رزم بخارا گزید
# predicted SOS که و و و <EOS>
# source چو شد گرسنه تیز پران عقاب
# target سوی گوشت کردند هر یک شتاب
# predicted SOS که و و و <EOS>
# source بپوشید درع سواران جنگ
# target نبود اندر ان کار جای درنگ
# predicted SOS که و و و <EOS>
# source بفرمود تا گاو دم بر درش
# target دمیدند و پر بانگ شد کشورش
# predicted SOS که و و و <EOS>
# 	Train Loss: 9.992e+01 | Train PPL: 2.491e+43
# ended in:  81.03528714179993 sec
# num of iterations is 128
# 100 4.7593
# source بمانیم تا سوی خاقان شود
# target چو بیمار شد نزد درمان شود
# predicted SOS به و و و <EOS>
# source بفرمود تا جامه ها خواستند
# target به خرگاه جایی بیاراستند
# predicted SOS به و و و <EOS>
# source که یزدانش تاج کیان برنهاد
# target همه شهریارانش فرخ نژاد
# predicted SOS به و و و <EOS>
# source بدو گفت زن من ترا بنده ام
# target بفرمان و رایت سرافگنده ام
# predicted SOS به و و و <EOS>
# source بدو گفت شاها ردا بخردا
# target بزرگا سترگا گوا موبدا
# predicted SOS به و و و <EOS>
# 	Train Loss: 1.032e+02 | Train PPL: 6.696e+44
# ended in:  81.6042845249176 sec
# num of iterations is 128
# 100 4.6404
# source جوان را بود روز پیری امید
# target نگردد سیه موی گشته سپید
# predicted SOS به و و و <EOS>
# source چو دشمن سپه کرد و شد تیز چنگ
# target بباید بسیچید ما را بجنگ
# predicted SOS به و و و <EOS>
# source هرانکس که از تخت من نیست شاد
# target ندارد همی پند شاهان بیاد
# predicted SOS به و و و <EOS>
# source هرانکس که زنده است ز ایرانیان
# target بیارم ببندم کمر بر میان
# predicted SOS به و و و <EOS>
# source چو دشمن بود شاه را کشته به
# target گر اواره از جنگ برگشته به
# predicted SOS به و و و <EOS>
# 	Train Loss: 1.000e+02 | Train PPL: 2.792e+43
# ended in:  79.37717962265015 sec
# num of iterations is 128
# 100 4.8000
# source پذیرم من ان پاک دین ورا
# target به جان برگزینم گزین ورا
# predicted SOS که و و و <EOS>
# source نگه کن سحرگاه تا بشنوی
# target ز بلبل سخن گفتنی پهلوی
# predicted SOS که و و و <EOS>
# source به کاووس گویم که این از منند
# target چنین کشته بر دست اهریمنند
# predicted SOS به و و و <EOS>
# source ز دشمن مکن دوستی خواستار
# target وگر چند خواند ترا شهریار
# predicted SOS که و و و <EOS>
# source چنین گفت با گیو بهرام شیر
# target که ای نامور نامدار دلیر
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.014e+02 | Train PPL: 1.048e+44
# ended in:  78.59303188323975 sec
# num of iterations is 128
# 100 4.7788
# source ازان پس چنین گفت کای بخردان
# target پسندیده و کار دیده ردان
# predicted SOS که و و و <EOS>
# source نگه کن بدین دشت با لشکری
# target تو در کشوری رستم از کشوری
# predicted SOS که و و و <EOS>
# source نیای تو پیری جهاندیده است
# target بتوران و چین در پسندیده است
# predicted SOS که و و و <EOS>
# source توخاقان چین را ببندی همی
# target گزند بزرگان پسندی همی
# predicted SOS که و و و <EOS>
# source فرستاده امد ز نزدیک شاه
# target به نزد سیاوش یکی نیک خواه
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.016e+02 | Train PPL: 1.369e+44
# ended in:  82.85090065002441 sec
# num of iterations is 128
# 100 4.8037
# source بدین خستگی نزد شاهت برم
# target ز کردارها بی گناهت برم
# predicted SOS که و و و <EOS>
# source چنین گفت کسری به پیش گروه
# target به مزدک که ای مرد دانش پژوه
# predicted SOS که و و و <EOS>
# source چنین است ایین گردنده دهر
# target گهی نوش بار اورد گاه زهر
# predicted SOS که و و و <EOS>
# source نیاطوس بگزید هفتاد مرد
# target که اورد گیرند روز نبرد
# predicted SOS که و و و <EOS>
# source بیا تا بسازیم سوگند و بند
# target براهی که اید دلت را پسند
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.024e+02 | Train PPL: 2.880e+44
# ended in:  80.42739486694336 sec
# num of iterations is 128
# 100 4.8659
# source چو امد به نزدیک تخت بلند
# target همان حقه بنهاد با مهر و بند
# predicted SOS که و و و <EOS>
# source سپاهی که هنگام ننگ و نبرد
# target ز جیحون بگردون براورد گرد
# predicted SOS که و و و <EOS>
# source به جنگت فرستاد نزد کسی
# target که همتا ندارد به گیتی بسی
# predicted SOS که و و و <EOS>
# source براورد بیدار دل جاثلیق
# target بران باره عراده و منجنیق
# predicted SOS که و و و <EOS>
# source به زابلستان گر درنگ اوریم
# target ز می باز پیگار و جنگ اوریم
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.030e+02 | Train PPL: 5.337e+44
# ended in:  79.37051463127136 sec
# num of iterations is 128
# 100 4.6975
# source گشاده شد ان مرز اباد بوم
# target سواری ندیدند جنگی بروم
# predicted SOS که و و و <EOS>
# source نگه کرد بیژن درفشش بدید
# target بدانست کو جست خواهد گزید
# predicted SOS که و و و <EOS>
# source اسیران وز خواسته چند چیز
# target فرستاد نزدیک خسرو بنیز
# predicted SOS که و و و <EOS>
# source به صد ترک بیچاره و بدنژاد
# target که نام پدرشان ندارید یاد
# predicted SOS که و و و <EOS>
# source ازو باد بر نامداران درود
# target بر اندازه هر یکی بر فزود
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.007e+02 | Train PPL: 5.489e+43
# ended in:  78.03369951248169 sec
# num of iterations is 128
# 100 4.6756
# source شبان زاده را دل پر از تخت بود
# target ورا پند ان موبدان سخت بود
# predicted SOS که و و و <EOS>
# source ابا خویشتن خادمان بر براه
# target ز راه و ز ایین شاهان مکاه
# predicted SOS که و و و <EOS>
# source بیامد نشست از بر گاه خویش
# target گرانمایگان را همه خواند پیش
# predicted SOS که و و و <EOS>
# source گرفتند پوزش که ما بنده ایم
# target هم از مهربانی سرافگنده ایم
# predicted SOS که و و و <EOS>
# source بهار امد و شد جهان چون بهشت
# target به خاک سیه بر فلک لاله کشت
# predicted SOS که و و و <EOS>
# 	Train Loss: 1.000e+02 | Train PPL: 2.766e+43
# ended in:  79.82240343093872 sec
# num of iterations is 128
